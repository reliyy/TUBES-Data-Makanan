# %%
#soal 1

def mirror_process(s):
    s_str = str(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 13
#      10     return huruf
#      12 s = str(input())
# ---> 13 print(mirror_process(s))
#
# Cell In[1], line 6, in mirror_process(s)
#       3 Alphabet = len(str(s))
#       5 for i in range(Alphabet):
# ----> 6     jumlah = s % 10
#       7     huruf = huruf * 10 + jumlah
#       8     s = s // 10
#
# TypeError: not all arguments converted during string formatting

# %%
#soal 2

def faktorial(n):
    if n == 1:
        return 1
    else:
        return n*faktorial(n - 1)

def Permutasi(x, y):
    faktorial(x) // faktorial(x - y)

def Combinasi(a, b):
    faktorial(a) // faktorial(b) * faktorial(a - b)

masukan = int(input())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[34], line 14
#      11     faktorial(a) // faktorial(b) * faktorial(a - b)
#      13 masukan = int(input())
# ---> 14 print(Permutasi(masukan))
#
# TypeError: Permutasi() missing 1 required positional argument: 'y'

# %%
#soal 3

def F(a):
    rumus = ((2(a) + 1) - 5) ** 2

def G(b):
    rumus = ((2(b ** 2) + 1) - 5)

def H(c):
    rumus = 2((c ** 2) - 5) + 1

masuk

# %%
#soal 4

# %%
#soal 5
